# %% [markdown]
# # 02 — Cleaning (ETL)
#
# Goal: clean + standardize the raw LendingClub dataset and write an analysis-ready file to `data/processed/`.
#
# Rules (from capstone):
# - Never edit the file in `data/raw/`.
# - Log/record every transformation.
# - Output the cleaned dataset to `data/processed/`.

# %% [markdown]
# ## Cleaning checklist (use this as your transformation log)
#
# - [ ] Read raw file from `data/raw/`
# - [ ] Standardize column names to `snake_case`
# - [ ] Parse dates (e.g., `issue_d`)
# - [ ] Convert percent strings to numeric (e.g., `int_rate`, `revol_util`)
# - [ ] Normalize categorical values (trim/case/typos)
# - [ ] Deduplicate (define rule + justify)
# - [ ] Missing value strategy per column (drop/impute/"Unknown")
# - [ ] Outlier policy for key numeric fields (cap/remove/flag)
# - [ ] Create derived fields needed for analysis (e.g., `is_default`, `issue_year`)
# - [ ] Save cleaned output to `data/processed/clean_lendingclub.csv`

# %%
from pathlib import Path

import numpy as np
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if (Path.cwd() / "notebooks").exists() else Path.cwd()
RAW_DIR = PROJECT_ROOT / "data" / "raw"
PROCESSED_DIR = PROJECT_ROOT / "data" / "processed"
RAW_DIR, PROCESSED_DIR

# %%
# TODO: set your raw filename after downloading
raw_file = ""
raw_path = RAW_DIR / raw_file
raw_path

# %%
# Example loader (adjust separator/encoding if needed)
# df_raw = pd.read_csv(raw_path, low_memory=False)
# df_raw.shape

# %% [markdown]
# ## Output
#
# Write a single Tableau-ready file (or a small set of well-documented outputs):
# - `data/processed/clean_lendingclub.csv`
